# %%
import os; print(os.popen('pip install hapiclient --upgrade').read())
import os; print(os.popen('pip install hapiplot --upgrade').read())
from hapiplot import hapiplot
from hapiclient import hapi

# %%
server     = 'https://vires.services/hapi'
dataset    = 'SW_OPER_EFIA_LP_1B'
parameters = 'Timestamp,Latitude,Longitude,Te'
start      = '2023-03-01T00:00:00.000000Z' 
stop       = '2023-03-02T00:00:00.000000Z'

# %%
data, meta = hapi(server, dataset, parameters, start, stop)
hapiplot(data, meta)
print(data)
# Out:
# [(b'2023-03-01T00:00:00.197Z',  55.1792129, 150.4607287, 3232.12919002)
#  (b'2023-03-01T00:00:00.696Z',  55.1473436, 150.4631563, 3223.27800198)
#  (b'2023-03-01T00:00:01.197Z',  55.1153465, 150.4655871, 3237.35701782)
#  ...
#  (b'2023-03-01T23:59:58.696Z', -67.7399705, 159.3932203, 2573.18915254)
#  (b'2023-03-01T23:59:59.197Z', -67.7716736, 159.4013869, 2762.57225264)
#  (b'2023-03-01T23:59:59.696Z', -67.8032497, 159.4095429, 3115.52195106)]
